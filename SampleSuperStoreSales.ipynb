# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Sample Superstore Dataset.csv',encoding='latin1')

# %%
df.head()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0  18606.0  Not Specified      0.01        2.88           0.50          2.0
# 1  20847.0           High      0.01        2.84           0.93          3.0
# 2  23086.0  Not Specified      0.03        6.68           6.15          3.0
# 3  23087.0  Not Specified      0.01        5.68           3.60          3.0
# 4  23088.0  Not Specified      0.00      205.99           2.50          3.0
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code  Order Date   Ship Date  \
# ...

# %%
df.isnull()
# Out:
#       Row ID  Order Priority  Discount  Unit Price  Shipping Cost  \
# 0      False           False     False       False          False
# 1      False           False     False       False          False
# 2      False           False     False       False          False
# 3      False           False     False       False          False
# 4      False           False     False       False          False
# ...      ...             ...       ...         ...            ...
# 9427    True            True      True        True           True
# 9428    True            True      True        True           True
# 9429    True            True      True        True           True
# 9430    True            True      True        True           True
# 9431    True            True      True        True           True
#
#       Customer ID  Customer Name  Ship Mode  Customer Segment  \
# 0           False          False      False             False
# ...

# %%
df.dropna()
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0     18606.0  Not Specified      0.01        2.88           0.50
# 1     20847.0           High      0.01        2.84           0.93
# 2     23086.0  Not Specified      0.03        6.68           6.15
# 3     23087.0  Not Specified      0.01        5.68           3.60
# 4     23088.0  Not Specified      0.00      205.99           2.50
# ...       ...            ...       ...         ...            ...
# 9421  20275.0       Critical      0.06       35.89          14.72
# 9422  20276.0       Critical      0.00        3.34           7.49
# 9423  24491.0  Not Specified      0.08      550.98          45.70
# 9424  25914.0           High      0.10      105.98          13.99
# 9425  24492.0  Not Specified      0.09        7.78           2.50
#
#       Customer ID    Customer Name       Ship Mode Customer Segment  \
# 0             2.0  Janice Fletcher     Regular Air        Corporate
# ...

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.strip()

# %%
df.head()
# Out:
#     row id order priority  discount  unit price  shipping cost  customer id  \
# 0  18606.0  Not Specified      0.01        2.88           0.50          2.0
# 1  20847.0           High      0.01        2.84           0.93          3.0
# 2  23086.0  Not Specified      0.03        6.68           6.15          3.0
# 3  23087.0  Not Specified      0.01        5.68           3.60          3.0
# 4  23088.0  Not Specified      0.00      205.99           2.50          3.0
#
#      customer name    ship mode customer segment product category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     region state or province       city  postal code  order date   ship date  \
# ...

# %%
df['profitmargin']=(df['profit']/df['sales'])*100

# %%
df['revenue']=df['sales']*(1-df['discount'])

# %%
df.columns=df.columns.str.replace(' ','')

# %%
df.columns
# Out:
# Index(['rowid', 'orderpriority', 'discount', 'unitprice', 'shippingcost',
#        'customerid', 'customername', 'shipmode', 'customersegment',
#        'productcategory', 'productsub-category', 'productcontainer',
#        'productname', 'productbasemargin', 'region', 'stateorprovince', 'city',
#        'postalcode', 'orderdate', 'shipdate', 'profit', 'quantityorderednew',
#        'sales', 'orderid', 'profitmargin', 'revenue'],
#       dtype='object')

# %%
df.head()
# Out:
#      rowid  orderpriority  discount  unitprice  shippingcost  customerid  \
# 0  18606.0  Not Specified      0.01       2.88          0.50         2.0
# 1  20847.0           High      0.01       2.84          0.93         3.0
# 2  23086.0  Not Specified      0.03       6.68          6.15         3.0
# 3  23087.0  Not Specified      0.01       5.68          3.60         3.0
# 4  23088.0  Not Specified      0.00     205.99          2.50         3.0
#
#       customername     shipmode customersegment  productcategory  ...  \
# 0  Janice Fletcher  Regular Air       Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air       Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air       Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air       Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air       Corporate       Technology  ...
#
#         city postalcode   orderdate    shipdate    profit quantityorderednew  \
# ...

# %%
import matplotlib.pyplot as py
import seaborn as sns

# %%
df.groupby('orderdate')['sales'].sum().plot(figsize=(20,5))
py.title('sales over time')
py.show()

# %%
sns.barplot(x='region',y='sales',data=df)
py.title('Region sales')
py.show()

# %%
df.to_csv('Sample Superstore Dataset.csv',index='false')

# %%
from google.colab import files
files.download('Sample Superstore Dataset.csv')
